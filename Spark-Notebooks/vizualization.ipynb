# %%
import pandas as pd
import matplotlib.pyplot as plt
from pyspark.sql.functions import col, explode,current_date, datediff,from_unixtime, expr, avg
from pyspark.sql.types import IntegerType
from datetime import datetime
# Out:
# StatementMeta(mySparkPool, 7, 2, Finished, Available)

# %%
# %%pyspark
# df_accounts = spark.read.load('abfss://synapse@jgastorage.dfs.core.windows.net/accounts.json', format='json')
#
# df_accounts.printSchema()
#
# df_accounts.show()
# Out:
# StatementMeta(mySparkPool, 7, 3, Finished, Available)
# root
#  |-- _id: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- account_id: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- limit: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- products: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#
# +--------------------+----------+-------+--------------------+
# |                 _id|account_id|  limit|            products|
# +--------------------+----------+-------+--------------------+
# |{5ca4bbc7a2dd94ee...|  {371138}| {9000}|[Derivatives, Inv...|
# |{5ca4bbc7a2dd94ee...|  {557378}|{10000}|[InvestmentStock,...|
# |{5ca4bbc7a2dd94ee...|  {198100}|{10000}|[Derivatives, Cur...|
# |{5ca4bbc7a2dd94ee...|  {674364}|{10000}|   [InvestmentStock]|
# |{5ca4bbc7a2dd94ee...|  {278603}|{10000}|[Commodity, Inves...|
# |{5ca4bbc7a2dd94ee...|  {383777}|{10000}|[CurrencyService,...|
# |{5ca4bbc7a2dd94ee...|  {794875}| {9000}|[InvestmentFund, ...|
# |{5ca4bbc7a2dd94ee...|  {328304}|{10000}|[Derivatives, Inv...|
# |{5ca4bbc7a2dd94ee...|  {487188}|{10000}|[Brokerage, Curre...|
# |{5ca4bbc7a2dd94ee...|  {910579}|{10000}|[Brokerage, Inves...|
# |{5ca4bbc7a2dd94ee...|  {260499}|{10000}|[InvestmentFund, ...|
# |{5ca4bbc7a2dd94ee...|  {668949}|{10000}|[Brokerage, Curre...|
# |{5ca4bbc7a2dd94ee...|  {976027}|{10000}|[Brokerage, Inves...|
# |{5ca4bbc7a2dd94ee...|  {135185}|{10000}|[CurrencyService,...|
# |{5ca4bbc7a2dd94ee...|  {370583}|{10000}|[Brokerage, Commo...|
# |{5ca4bbc7a2dd94ee...|  {870466}|{10000}|[Derivatives, Bro...|
# |{5ca4bbc7a2dd94ee...|  {692278}|{10000}|[Commodity, Inves...|
# |{5ca4bbc7a2dd94ee...|  {864905}|{10000}|[Commodity, Inves...|
# |{5ca4bbc7a2dd94ee...|  {299072}|{10000}|[InvestmentFund, ...|
# |{5ca4bbc7a2dd94ee...|  {137994}|{10000}|[CurrencyService,...|
# +--------------------+----------+-------+--------------------+
# only showing top 20 rows

# %%
# %%pyspark
# df_customers = spark.read.load('abfss://synapse@jgastorage.dfs.core.windows.net/customers.json', format='json')
#
# df_customers.printSchema()
#
# df_customers.show()
# Out:
# StatementMeta(mySparkPool, 7, 6, Finished, Available)
# root
#  |-- _id: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- accounts: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |-- active: boolean (nullable = true)
#  |-- address: string (nullable = true)
#  |-- birthdate: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- tier_and_details: struct (nullable = true)
#  |    |-- 0134c72f17e3419cbdc857171cbb5651: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 01c680e72a154c3abb7e3c71a8848553: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 022451f21d6749c397cbe216ccd16a6e: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 03c88083e11a4c96a994c20a2843f6f4: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 03e0e614ac404302ae6172eff45917e3: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 04ac832f3eba4c49b4bf57dec8765f84: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 04afa74bf41d4a698e82670c34178809: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 06408794cad9415882ad850f606e2215: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 069f84c793a14fa891f716cf09314062: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0799f1cfba5645fdbb6e1463521c796a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 07d516cfd7fc4ec6acf175bb78cb98a2: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 083f840a514846558cd0f2d7cc64bea7: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0b35f2c1bb564a6bb539eb08ad12a42c: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0bb6b872125e475c919b77799ffe1094: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0d40b35ba9b640468bbc711ef35cd7cc: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0db0e5c9a332493ea75f70d028ed36e8: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0dceb4760e4b409da9414a1b676dfbc6: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0df078f33aa74a2e9696e0520c1a828a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0e025e0c398f412b854c0c5e5200efd3: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0f3d640b61e04acb877fd8373d465dc3: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0f415868bc0b4acfa9160adf1b840fa9: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0f4bd4b6eb8e46a7a8db87a39f7bca8a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0f721694c5d54b5e9470a48ab2532b83: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 0fc5e69934734bedab14092ebf9a3ef1: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 10427cb061044a278c0eb394ef2ad11e: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1061d02dd9d944acb129d0b7dc9838b1: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 10b960b817ae432fb8516d7adb4b092b: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 11d77bf98b3c44c397f7ff5c2d3c89dc: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 11dc1f3c5d7545e0bd8626d9d9e8f4ae: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 11e3a0bb90844b49be054f9723eebcae: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 12f025d4039d4ae69530e2ec65d134d8: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1399c72f5aa741b6b9cb497837f55aa2: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 142ac5781d314f659023117057488a6c: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 14540f8bc96947fdb620f52768acce16: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 14b8d7848c14493dbb380abeb677db1b: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 150584fabf0346ceadbfb329b9f6a98c: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 153755224a544887b611dc046ae8a701: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 156adfcaa2ff4a7b8793ceaa216008d2: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1768a44b906c4303b765ea38b1b4bbb2: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 178843ff3bed4b75954bb8d7cf332d70: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 19b3750896e748e08b769539e08bf436: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 19e2c6ccebcc4d69bc8b807980b7dfe8: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1a293928a7344fc28d8e42485eeb1c77: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1b3cdcb5287744beb8b0a0bb53f6816d: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1b606261cefd4bcbbf02de3313610492: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1c0357589b88465ab8e813d287700830: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1c6679a4fda54e5d9126128711d682da: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1cf4ce3efef840c2ae4b0f66bc0a8e55: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1e220b99759845508cacdca9313a5fc5: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1e64a51089c54d08911baf77be6b3713: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1f6047657041457d9a77a3a3cce687ff: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 1fe9e1c65acf4a969c498685c2521a3f: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2248f01694684922ac493ae54808ad0b: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 237143b0bea944409c529daf1f38027b: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2371815278ce47f18f4d384b91183d2c: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 243324baedf24266b36264daac98117a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 244a43ff263b4e35adbac1a60ee1dac7: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 262951da826d461e962db6115b78e85c: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 27e7c8ab86384915996f987d7dcb3ca7: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 27f5804deaa2459ea1102a8d784876a2: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 28440204c6da475d8e78f42b1550a6e0: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 28cf2d66a5944fa8a4c0ac9725ad1b62: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 28fa137392554682927d0a71b2d4e89a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2a3cec81cd26455499355a9098611ab0: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2a4e63af172f4ecbbdf6b9dd3f28d8d2: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2a813dffd08540e0ae57733110199c84: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2ab8732262794f9faa36757f97cb9280: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2b558fe1fa70429ba01e2ac2307ad495: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2cf11f6f194c4504821dbe26d2543bee: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2eb4b72c91eb4be3833f8a30f675db62: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2ecc798c157e47d49cee73769507f76d: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2ed001ce9a4442a6a2974335966136fc: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2f4891146b2f4f4f9f353d4ddc016149: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 2fa99e0e672543d8ad9ef11779d8b81a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 3124cc130f624526aab5ea439f21f69e: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 315dc7a8ba9e457b938697fa5a48d104: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 319d4668c59a4990b7724f7110ed56c1: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 321cdec924004fd79eaecd14de883ae4: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 32ad086469014f26b9e30b1c64bbb322: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 338334448f824daf8f60cd3880f54d3a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 348e127cf32e462c9d5518dbca3b0d83: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 35d24ecf370e4e21ba65dbe49e44d811: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 35f3364970214bb786b79b592b4d39b8: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 361f3f6e50fc416eaad9043e3ede9962: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 36d50ad14fa240ee9fe8b1e40ae616aa: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 37c16a6151f3475491cacddcccd770dc: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 39020d9db81a46d08f586365a5076aea: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 3986916269594d61951dc8fff17beee7: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 3a2b834e068945e2913b5eea8cc676c2: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 3a2c2a6d7c65480fbf64d29ae7542481: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 3a6e1b4d345b49c3b68eb640ee374d05: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 3c314ff0b9b44ef88def490f96e7ea77: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 3cd1f7d258804aebb4990cc32228d72e: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 3e05a76a2fc24390b1fb34b0148433f9: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 3ea13ed43fce4e87bf473e33b725b4dc: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 400aa61d323a492f9688b99a8ada975c: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 40694ad70cf7489aa179d0c7b315d464: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 407442b8856c4f6fae5be1e8a445b574: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4093a98f922b4e0188c875f4ab22333f: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 419a8f695c5049369701c23f37c75314: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 420fc4bc96e2435abbf1a5973ed39cc0: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 42f70f67199947818d4d256412c91e22: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 43f54863661d4405942976c0d95dcdd3: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4456cae1667c4e6495e7f3578c5573c0: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 44589276e6f84ed58ada0ad0887f2492: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 44ded6fe7e5a48d4bb38907f49603e93: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 45133ca42f354b439702aadaf550fd61: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 457228a40d1d4a2696772c34ce736a18: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 458e6b9ea2444d6f9b4b5e9e21ca685c: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4611c2a5c4404ac1ab1fe5e4a98ef273: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4656ca6cf342445dbc024429fe6fef64: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 48dde6e108654d83aed0a74e7ed0aede: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 48ec215de4be4f63a437af44fb1d0f25: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 496aed84abe64de3a43eba9be7442a60: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 49c2662c8dad4de59259cddaecb53387: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4a4d209a65614639aa98f7a3e222b70d: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4a6826f6881f48d7ac6c9c7b2e352a07: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4b4dadf08b564e81b98b2c5d253433c6: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4c207e65857742f89d8155139b24c0f0: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4d474eebd26a421fb51ed963748c310b: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4d58f15e1d2a4006b7dbedb1a3583de9: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4d6c58a55242420090093cd7cd29b6ca: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4d75e63fe2ea441fa9f9376a72d88e5e: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4eb87d785d9849a098728185bad74bda: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4eef8924463241d6a0d8e4234f1ccedb: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 4f32fd5f1af547e7aa907fa3e64ae024: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 508e6a9ea7a64740a06817764e9e5e72: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 50fb121e828d4160844d9277ad978832: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 513dad091920468fa108583310cf15cd: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 521b42a905424ccd9da23c436e2c5cf4: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 525b0388e0904f17958cc3a7d56b9d6d: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 52e40a6c36aa4f9f91093cd1923ef2e6: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 5357e9de3cbd4470959193d5e43ed87b: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 537f1f089c7548cca95481b0422d0b2c: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 53d85cf6672244e3a4008b09fe6bd0e3: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 545c5449ab1a4df0953c60d6ecc38fd5: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 54bfcfe250bb495ca9377546b4b90f07: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 5516e45ad15c4eabb29dcf503ec986d2: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 55429058eda14f3ebe9cf7b852fbc1d1: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 55edd93016f5405290ef4dcd1f591d38: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 564efb88e27b4bd5ac8bd25a6404545d: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 56a2451072744942a4347b663a21948c: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 58d241387876450b9bcbc24725a7ef65: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 58d44bf31dca4680b2552f67631ecc90: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 5904cb3441ab4d26ac13059b8326f063: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 59774b0c0b04468880fb336fd2d82d6b: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 59ee9884093f41cc94b4b59e81655bf4: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 5a16ade9bc0d4d52a3c1a307cb1aec86: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 5c5bc5f550f84dfb90ff16b565855eeb: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 5cb805661d8f4fad9290fbd0976bb95a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- 5cf7677f0e2b4caabe9d6e6eeccd977c: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
# ...
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- eb2bb3a96baf4c0584e142477f076173: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- eb491d3a7c8d408980b29297a23a5524: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- eb5a061c4a2745d099c7401d0bfd24b0: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- ebd331efeda04114a6b06259cf1ba593: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- eccdc19282be4c42b79504c71d23937a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- eccee50ae803455db26446538f829853: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- efa1a806ee8c4edab6fcbb50fa8a4466: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f07f745fd4864b57897182a34303c302: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f08c1d808d3548d8a4081558446bab8b: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f1c61c41478f40268922381d0ee69e2b: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f29b6a65fce74702a4aa550b704482a6: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f2cb0bcb11f34deb819f285c9147683f: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f2e43dbe067a4a3db9132ecd41e4e188: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f482b700b16e4a60a9bb5d7ab57d9bc5: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f4b3cac99b4343afb37cd705eb0bf52a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f4bbce2aa89c476c9950d966ffb7b070: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f4ccc57442504cddbc5002e720e4a2e5: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f4cebafe5530421b991303dff297643d: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f5058d7647044c67b6fb5bd5f2d8977b: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f53114edcec9451fbc3f9afe338be373: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f579bde3688f4fc3a43448590c20d57b: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f57b65733ddd4600a2db53450b0f539a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f5e14e1ddad14b5abcf0aa01c0b81896: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f6c0be1f3e1a4b88b0596c74dc3b7ce0: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f818540428174b89bc7060618facc97d: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f88ad60ef0c947418de6810f8e4b54a5: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- f91656af0a594a86ae7da2897b5de7fe: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- fa009b4a1ffa4a4084553358c20075f1: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- fa8456a2fc0e4688b54d4911b1a3b3fe: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- fb7606a128e143fdb048f8b844c1ad03: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- fbb87b7c7aa24281944235f03e0388f2: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- fc22c1e6871a43508551dcbcb0c04166: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- fc5d37e64ce743428d1da6d6604d49da: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- fd5c1548e4f842d1aa7c0b32c787da5a: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- fed95ed54add49fc8d3e26719b8ebc3e: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- ff074044a60c40e7845f3682800d4475: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |    |-- ff21cb033e7e4aae8921877f68fd5d58: struct (nullable = true)
#  |    |    |-- active: boolean (nullable = true)
#  |    |    |-- benefits: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- tier: string (nullable = true)
#  |-- username: string (nullable = true)
#
# +--------------------+--------------------+------+--------------------+----------------+--------------------+-----------------+--------------------+----------------+
# |                 _id|            accounts|active|             address|       birthdate|               email|             name|    tier_and_details|        username|
# +--------------------+--------------------+------+--------------------+----------------+--------------------+-----------------+--------------------+----------------+
# |{5ca4bbcea2dd94ee...|[{371138}, {32428...|  true|9286 Bethany Glen...|{{226117231000}}|arroyocolton@gmai...|    Elizabeth Ray|{null, null, null...|         fmiller|
# |{5ca4bbcea2dd94ee...|          [{116508}]|  null|Unit 1047 Box 408...|{{761701587000}}|cooperalexis@hotm...|    Lindsay Cowan|{null, null, null...|valenciajennifer|
# |{5ca4bbcea2dd94ee...|[{462501}, {22829...|  null|55711 Janet Plaza...|{{582848134000}}|timothy78@hotmail...|  Katherine David|{null, null, null...|      hillrachel|
# |{5ca4bbcea2dd94ee...|[{170945}, {951849}]|  null|Unit 2676 Box 935...|{{154708220000}}| tcrawford@gmail.com|  Leslie Martinez|{null, null, null...|    serranobrian|
# |{5ca4bbcea2dd94ee...|[{721914}, {81722...|  null|2765 Powers Meado...|{{231803855000}}|  dustin37@yahoo.com|    Brad Cardenas|{null, null, null...|   charleshudson|
# |{5ca4bbcea2dd94ee...|[{904260}, {565468}]|  null|17677 Mark Crest\...|{{842634867000}}|amyholland@yahoo.com|     Natalie Ford|{null, null, null...| gregoryharrison|
# |{5ca4bbcea2dd94ee...|[{627629}, {55958...|  null|50047 Smith Point...|{{-16752040000}}| vcarter@hotmail.com|      Dana Clarke|{null, null, null...|          hmyers|
# |{5ca4bbcea2dd94ee...|[{385397}, {33797...|  null|633 Miller Turnpi...|{{730661849000}}|   laura34@yahoo.com|     Gary Nichols|{null, null, null...|  andrewhamilton|
# |{5ca4bbcea2dd94ee...|[{702610}, {240640}]|  null|38456 Rachael Cau...|{{732022654000}}|   zmelton@gmail.com|       John Parks|{null, null, null...|      matthewray|
# |{5ca4bbcea2dd94ee...|[{344885}, {83992...|  null|4140 Pamela Hollo...| {{90241268000}}|   scott50@yahoo.com|Jennifer Lawrence|{null, null, null...|          glopez|
# |{5ca4bbcea2dd94ee...|          [{987709}]|  null|8681 Karen Roads ...| {{95789846000}}|josephmacias@hotm...|    James Sanchez|{null, null, null...|        wesley20|
# |{5ca4bbcea2dd94ee...|[{662207}, {816481}]|  null|18637 Jessica Rid...|{{627927174000}}|michael16@hotmail...|     Ashley Lopez|{null, null, null...|     thomasdavid|
# |{5ca4bbcea2dd94ee...|          [{571880}]|  null|2129 Joel Rapids\...|{{235600552000}}|michaelespinoza@g...| Dr. Angela Brown|{null, null, null...|      patricia44|
# |{5ca4bbcea2dd94ee...|[{88112}, {567199...|  null|86636 Maria Viadu...|{{432962538000}}|  ryanpena@yahoo.com|        John Vega|{null, null, null...|     nelsonmaria|
# |{5ca4bbcea2dd94ee...|[{883283}, {98086...|  null|1579 Young Trail\...|{{341598359000}}|briannafrost@yaho...|     Lauren Clark|{null, null, null...|   portermichael|
# |{5ca4bbcea2dd94ee...|[{631901}, {814687}]|  null|USNS Howard\nFPO ...|{{399712377000}}|virginia36@hotmai...|Jacqueline Haynes|{null, null, null...|   johnsonshelly|
# |{5ca4bbcea2dd94ee...|[{550665}, {321695}]|  null|70092 Adams Prair...|{{286857767000}}|   april04@gmail.com|     Brian Flores|{null, null, null...|    hunterdaniel|
# |{5ca4bbcea2dd94ee...|[{66698}, {859246...|  null|7322 Owens Inlet ...|{{156860840000}}|   omolina@gmail.com|Christopher Gomez|{null, null, null...|         james75|
# |{5ca4bbcea2dd94ee...|[{205563}, {61660...|  null|86176 Katherine C...|{{648222432000}}|barbaraduncan@gma...|     Robert Burns|{null, null, null...|          eric10|
# |{5ca4bbcea2dd94ee...|[{700880}, {37684...|  null|932 Jeremy Spring...|{{363566100000}}|nicoleanderson@ho...|    Joshua Parker|{null, null, null...|     millerrenee|
# +--------------------+--------------------+------+--------------------+----------------+--------------------+-----------------+--------------------+----------------+
# only showing top 20 rows

# %%
# %%pyspark
# df_transactions = spark.read.load('abfss://synapse@jgastorage.dfs.core.windows.net/transactions.json', format='json')
#
# df_transactions.printSchema()
# Out:
# StatementMeta(mySparkPool, 7, 7, Finished, Available)
# root
#  |-- _id: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- account_id: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- bucket_end_date: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- bucket_start_date: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- transaction_count: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- transactions: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- amount: struct (nullable = true)
#  |    |    |    |-- $numberInt: string (nullable = true)
#  |    |    |-- date: struct (nullable = true)
#  |    |    |    |-- $date: struct (nullable = true)
#  |    |    |    |    |-- $numberLong: string (nullable = true)
#  |    |    |-- price: string (nullable = true)
#  |    |    |-- symbol: string (nullable = true)
#  |    |    |-- total: string (nullable = true)
#  |    |    |-- transaction_code: string (nullable = true)
